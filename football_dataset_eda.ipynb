# %% [markdown]
# <a href="https://colab.research.google.com/github/pknemi/Data-visualization-Tasks/blob/main/football_dataset_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("kl.csv",encoding="latin1")
df
# Out:
#        Unnamed: 0      ID                Name   Age  \
# 0               0  158023            L. Messi  31.0
# 1               1   20801   Cristiano Ronaldo  33.0
# 2               2  190871           Neymar Jr  26.0
# 3               3  193080              De Gea  27.0
# 4               4  192985        K. De Bruyne  27.0
# ...           ...     ...                 ...   ...
# 18202       18202  238813        J. Lundstram  19.0
# 18203       18203  243165  N. Christoffersson  19.0
# 18204       18204  241638           B. Worman  16.0
# 18205       18205  246268      D. Walker-Rice  17.0
# 18206       18206  246269           G. Nugent  16.0
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
df.shape
# Out:
# (18207, 89)

# %%
df1=df[["Name","Age","Nationality","Overall","Potential","Club","Value","Wage","International Reputation","Position","Stamina","Acceleration","Finishing"]]
df1
# Out:
#                      Name   Age Nationality  Overall  Potential  \
# 0                L. Messi  31.0   Argentina     94.0         94
# 1       Cristiano Ronaldo  33.0    Portugal     94.0         94
# 2               Neymar Jr  26.0      Brazil     92.0         93
# 3                  De Gea  27.0       Spain     91.0         93
# 4            K. De Bruyne  27.0     Belgium     91.0         92
# ...                   ...   ...         ...      ...        ...
# 18202        J. Lundstram  19.0     England     47.0         65
# 18203  N. Christoffersson  19.0      Sweden     47.0         63
# 18204           B. Worman  16.0     England     47.0         67
# 18205      D. Walker-Rice  17.0     England     47.0         66
# 18206           G. Nugent  16.0     England     46.0         66
#
#                       Club        Value      Wage  International Reputation  \
# 0             FC Barcelona  110500000.0  565000.0                       5.0
# ...

# %% [markdown]
# Top 10 Players

# %%
Top=df1.sort_values(by="Overall",ascending=False).head(10)
Top
# Out:
#                  Name   Age Nationality  Overall  Potential  \
# 0            L. Messi  31.0   Argentina     94.0         94
# 1   Cristiano Ronaldo  33.0    Portugal     94.0         94
# 2           Neymar Jr  26.0      Brazil     92.0         93
# 3              De Gea  27.0       Spain     91.0         93
# 4        K. De Bruyne  27.0     Belgium     91.0         92
# 5           E. Hazard  27.0     Belgium     91.0         91
# 6           L. Modri?  32.0     Croatia     91.0         91
# 7           L. Suárez  31.0     Uruguay     91.0         91
# 8        Sergio Ramos  32.0       Spain     91.0         91
# 12           D. Godín  32.0     Uruguay     90.0         90
#
#                    Club    Value   Wage  International Reputation Position  \
# 0          FC Barcelona  110.5M  565K                       5.0       RF
# 1              Juventus     77M  405K                       5.0       ST
# 2   Paris Saint-Germain  118.5M  290K                       5.0       LW
# ...

# %% [markdown]
# Top 10 Players

# %%
plt.style.use("classic")
plt.bar(Top["Name"],Top["Overall"],color="aqua")
plt.xticks(rotation=90)
plt.ylim(85,100)
plt.title("Top 10 Players")
plt.xlabel("Players")
plt.ylabel("Rating")
# Out:
# Text(0, 0.5, 'Rating')

# %% [markdown]
# **Among World's Top Rated Players,L.Messi is  top in the list followed by c.ronaldo**

# %% [markdown]
# positional distribution

# %%
position_dist=df1["Position"].value_counts().head(10)
position_dist
# Out:
# ST     2152
# GK     2025
# CB     1778
# CM     1394
# LB     1322
# RB     1291
# RM     1124
# LM     1095
# CAM     958
# CDM     948
# Name: Position, dtype: int64

# %%
plt.figure(figsize=(8,8))
plt.pie(position_dist,labels=position_dist.index,autopct="%1.1f%%")
plt.title("Positional Distribution")
plt.legend(loc="upper right",bbox_to_anchor=(1.5,1))

# %% [markdown]
# **Around 15.3% of the players are Strikers,Only 6.7% are central defence psition holders**

# %%
pen=df[["Name","Penalties"]]

tp=pen.sort_values(by="Penalties",ascending=False).head(10)
tp
# Out:
#                Name  Penalties
# 206    M. Balotelli       92.0
# 118         Fabinho       91.0
# 16          H. Kane       90.0
# 297        M. Kruse       90.0
# 945       L. Baines       90.0
# 507    R. Boudebouz       90.0
# 384      D. Perotti       90.0
# 823      R. Jiménez       90.0
# 109  Z. Ibrahimovi?       89.0
# 68          M. Reus       89.0

# %%
plt.style.use("classic")
plt.bar(tp["Name"],tp["Penalties"],color="red")
plt.xticks(rotation=90)
plt.ylim(85,100)
plt.title(" Penalty Accuracy")
plt.xlabel("Players")
plt.ylabel("penality")
# Out:
# Text(0, 0.5, 'penality')

# %%
plt.figure(figsize=(8,8))
plt.style.use("dark_background")
plt.bar(Top["Name"],Top["Stamina"],color="red")
plt.xticks(rotation=90)
plt.ylim(40,100)
plt.title("Players with High Stamina")
plt.xlabel("Players")
plt.ylabel("Stamina")
# Out:
# Text(0, 0.5, 'Stamina')

# %% [markdown]
# **K.De Bruyne and L.Suarez are the players with highest stamina followed closely by Cristiano Ronaldo**

# %%
Nat=df1["Nationality"].value_counts().head(10)
Nat
# Out:
# England        1662
# Germany        1198
# Spain          1072
# Argentina       937
# France          914
# Brazil          827
# Italy           702
# Colombia        618
# Japan           478
# Netherlands     453
# Name: Nationality, dtype: int64

# %%
plt.figure(figsize=(8,8))
plt.pie(Nat,labels=Nat.index,autopct="%1.1f%%")
plt.title("National distribution of players")

plt.legend(loc="upper right",bbox_to_anchor=(1.5,1))

# %% [markdown]
# **Most Number of soccer Players Are from England,followed by Germany**

# %%
def convert_value(value):
    if value.endswith('M'):
        return float(value[1:-1]) * 1000000
    elif value.endswith('K'):
        return float(value[1:-1]) * 1000
    else:
        return float(value[1:])

# %%
df['Value'] = [convert_value(value) for value in df['Value']]

# %%
df["Wage"]
# Out:
# 0        565000.0
# 1        405000.0
# 2        290000.0
# 3        260000.0
# 4        355000.0
#            ...
# 18202      1000.0
# 18203      1000.0
# 18204      1000.0
# 18205      1000.0
# 18206      1000.0
# Name: Wage, Length: 18207, dtype: float64

# %%
df4=df[["Value","Name","Club"]]
df4
# Out:
#              Value                Name                 Club
# 0      110500000.0            L. Messi         FC Barcelona
# 1       77000000.0   Cristiano Ronaldo             Juventus
# 2      118500000.0           Neymar Jr  Paris Saint-Germain
# 3       72000000.0              De Gea    Manchester United
# 4      102000000.0        K. De Bruyne      Manchester City
# ...            ...                 ...                  ...
# 18202      60000.0        J. Lundstram      Crewe Alexandra
# 18203      60000.0  N. Christoffersson       Trelleborgs FF
# 18204      60000.0           B. Worman     Cambridge United
# 18205      60000.0      D. Walker-Rice      Tranmere Rovers
# 18206      60000.0           G. Nugent      Tranmere Rovers
#
# [18207 rows x 3 columns]

# %%
Top_value=df1.sort_values(by="Value",ascending=False).head(10)
Top_value
# Out:
#               Name   Age Nationality  Overall  Potential                 Club  \
# 2        Neymar Jr  26.0      Brazil     92.0         93  Paris Saint-Germain
# 0         L. Messi  31.0   Argentina     94.0         94         FC Barcelona
# 4     K. De Bruyne  27.0     Belgium     91.0         92      Manchester City
# 5        E. Hazard  27.0     Belgium     91.0         91              Chelsea
# 15       P. Dybala  24.0   Argentina     89.0         94             Juventus
# 16         H. Kane  24.0     England     89.0         91    Tottenham Hotspur
# 25       K. Mbappé  19.0      France     88.0         95  Paris Saint-Germain
# 7        L. Suárez  31.0     Uruguay     91.0         91         FC Barcelona
# 17    A. Griezmann  27.0      France     89.0         90      Atlético Madrid
# 10  R. Lewandowski  29.0      Poland     90.0         90    FC Bayern München
#
#           Value      Wage  International Reputation Position  Stamina  \
# ...

# %% [markdown]
# Most Valued players

# %%
plt.style.use("dark_background")
plt.bar(Top_value["Name"],Top_value["Value"],color="cyan")
plt.xticks(rotation=90)

plt.title("players and their value")
plt.xlabel("Players")
plt.ylabel("value")
# Out:
# Text(0, 0.5, 'value')

# %% [markdown]
#  **Naymar is the most valued player followed by L.messi**

# %%
High_valued_club=df.groupby("Club")["Value"].sum().sort_values(ascending=False).head(10)
High_valued_club
# Out:
# Club
# Real Madrid            874425000.0
# FC Barcelona           852600000.0
# Manchester City        786555000.0
# Juventus               704475000.0
# FC Bayern München      679025000.0
# Atlético Madrid        644525000.0
# Paris Saint-Germain    625325000.0
# Tottenham Hotspur      618450000.0
# Chelsea                606815000.0
# Manchester United      588850000.0
# Name: Value, dtype: float64

# %%
plt.pie(High_valued_club,labels=High_valued_club.index,autopct="%1.1f%%")
plt.title("Club distribution based on their value")
plt.legend(loc="upper right",bbox_to_anchor=(2,1))

# %% [markdown]
# **Real Madrid is the most valuable soccer team followed closely by Barcelona**

# %%
def convert_value(value):
    if value.endswith('M'):
        return float(value[1:-1]) * 1000000
    elif value.endswith('K'):
        return float(value[1:-1]) * 1000
    else:
        return float(value[1:])

# %%
df["Wage"]
# Out:
# 0        565K
# 1        405K
# 2        290K
# 3        260K
# 4        355K
#          ...
# 18202      1K
# 18203      1K
# 18204      1K
# 18205      1K
# 18206      1K
# Name: Wage, Length: 18207, dtype: object

# %%
df['Wage'] = [convert_value(value) for value in df['Wage']]

# %%
df["Wage"]
# Out:
# 0        565000.0
# 1        405000.0
# 2        290000.0
# 3        260000.0
# 4        355000.0
#            ...
# 18202      1000.0
# 18203      1000.0
# 18204      1000.0
# 18205      1000.0
# 18206      1000.0
# Name: Wage, Length: 18207, dtype: float64

# %%
High_paid_player=df.sort_values(by="Wage",ascending=False).head(10)
High_paid_player
# Out:
#     Unnamed: 0      ID               Name   Age  \
# 0            0  158023           L. Messi  31.0
# 7            7  176580          L. Suárez  31.0
# 6            6  177003          L. Modri?  32.0
# 1            1   20801  Cristiano Ronaldo  33.0
# 8            8  155862       Sergio Ramos  32.0
# 11          11  182521           T. Kroos   NaN
# 36          36  173731            G. Bale  28.0
# 4            4  192985       K. De Bruyne  27.0
# 5            5  183277          E. Hazard  27.0
# 32          32  189242           Coutinho  26.0
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 7   https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# 6   https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 1    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 8   https://cdn.sofifa.org/players/4/19/155862.png       Spain
# ...

# %%
plt.style.use("dark_background")
plt.bar(High_paid_player["Name"],High_paid_player["Wage"],color="brown")
plt.xticks(rotation=90)
plt.title("Highest paid players")
plt.xlabel("players")
plt.ylabel("Wage")
# Out:
# Text(0, 0.5, 'Wage')

# %% [markdown]
# **As per the data,Messi is the highest paid footballer
# followed by Suarez**

# %%
clubs_group=df1.groupby("Club")

# %%
Rmp=clubs_group.get_group("Real Madrid").sort_values(by="Age",ascending=True)
Rmp_Age=Rmp["Age"].head(10)
Rmp_name=Rmp["Name"].head(10)
Rmp
# Out:
#                   Name   Age         Nationality  Overall  Potential  \
# 1143   Vinícius Júnior  17.0              Brazil     77.0         92
# 11327      Fran García  18.0               Spain     64.0         79
# 11877    Manu Hernando  19.0               Spain     64.0         76
# 11163     Sergio López  19.0               Spain     64.0         80
# 2513       F. Valverde  19.0             Uruguay     74.0         84
# 12504       Dani Gómez  19.0               Spain     63.0         77
# 13687        L. Zidane  20.0              France     62.0         71
# 10178  F. Feuillassier  20.0           Argentina     65.0         80
# 9141   Cristo González  20.0               Spain     66.0         78
# 10269          Fidalgo  21.0               Spain     65.0         75
# 8732      Javi Sánchez  21.0               Spain     67.0         79
# 6724          Reguilón  21.0               Spain     68.0         80
# 754            Vallejo  21.0               Spain     78.0         86
# ...

# %%
plt.plot(Rmp_name,Rmp_Age,color="black")
plt.xticks(rotation=90)
plt.title("Real Madrid players and their Age")
plt.xlabel("Name")
plt.ylabel("Age")
# Out:
# Text(0, 0.5, 'Age')

# %% [markdown]
# youngest player of Real Madrid is vinicius junior with 17 years old,followed by Fran Garcia

# %%
average_overall_rating_by_age=df1.groupby("Age")["Overall"].mean()
average_overall_rating_by_age
# Out:
# Age
# 16.0    54.452381
# 17.0    56.404844
# 18.0    57.741803
# 19.0    59.583008
# 20.0    61.858871
# 21.0    63.480675
# 22.0    64.994030
# 23.0    66.244745
# 24.0    67.306333
# 25.0    67.973465
# 26.0    68.500000
# 27.0    68.949225
# 28.0    69.194545
# 29.0    69.246090
# 30.0    69.695747
# 31.0    69.850071
# 32.0    69.529617
# 33.0    69.558824
# 34.0    69.539604
# 35.0    68.132653
# 36.0    67.937008
# 37.0    68.939024
# 38.0    67.378378
# 39.0    67.640000
# 40.0    67.692308
# 41.0    67.600000
# 42.0    65.000000
# 44.0    50.500000
# 45.0    71.000000
# Name: Overall, dtype: float64

# %%
df1["Age"].min()
# Out:
# 16.0

# %%
df1["Age"].max()
# Out:
# 45.0

# %%
age=df1["Age"]
bins=[16,20,30,45]
plt.hist(age,color="black",edgecolor="red",bins=bins)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("players count")
# Out:
# Text(0, 0.5, 'players count')

# %% [markdown]
# **Most of the players is from age group 20 to 30.**

# %%
plt.plot(average_overall_rating_by_age.index,average_overall_rating_by_age.values,color="red")

# %%
players_value=df1["Value"].head(20)
plt.violinplot(players_value)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x790834ef0a60>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x790834ef1270>,
#  'cmins': <matplotlib.collections.LineCollection at 0x790830be04f0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x790830be0e20>}

# %%
players_Accelaration=df1["Acceleration"].head(20)
plt.boxplot(players_Accelaration)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x79083375caf0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x79083375c070>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x79083375efb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x79083377c520>],
#  'fliers': [<matplotlib.lines.Line2D at 0x79083377c310>],
#  'means': []}
